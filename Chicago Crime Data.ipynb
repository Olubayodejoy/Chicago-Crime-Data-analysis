# %% [markdown]
# Chicago Crime Data
#
# Task: Load the dataset, filter crimes by type and date, and group by neighborhood to find crime rates.

# %%
import pandas as pd
import seaborn as sns
Chicago_Crime = pd.read_csv('C:\\Users\\HP\\Documents\\Crimes_-_2001_to_Present.csv')
Chicago_Crime
# Out:
#                ID Case Number                    Date                   Block  \
# 0        11646166    JC213529  09/01/2018 12:01:00 AM   082XX S INGLESIDE AVE
# 1        11645836    JC212333  05/01/2016 12:25:00 AM     055XX S ROCKWELL ST
# 2        11449702    JB373031  07/31/2018 01:30:00 PM  009XX E HYDE PARK BLVD
# 3        11643334    JC209972  12/19/2018 04:30:00 PM  056XX W WELLINGTON AVE
# 4        11645527    JC212744  02/02/2015 10:00:00 AM      069XX W ARCHER AVE
# ...           ...         ...                     ...                     ...
# 7842932  13128007    JG325985  06/21/2023 08:00:00 PM  031XX N CALIFORNIA AVE
# 7842933  13129172    JG327619  06/20/2023 04:00:00 AM   028XX N MAPLEWOOD AVE
# 7842934  13128066    JG325838  06/06/2023 03:42:00 PM    018XX N LOCKWOOD AVE
# 7842935  13128324    JG326502  05/13/2023 12:00:00 PM       020XX W CERMAK RD
# 7842936  13128375    JG326564  06/24/2023 01:29:00 PM    069XX N HAMILTON AVE
#
# ...

# %%
filtered10_df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 filtered10_df.info()
#
# NameError: name 'filtered10_df' is not defined

# %%
# Convert 'Date' to datetime format
Chicago_Crime['Date'] = pd.to_datetime(Chicago_Crime['Date'], errors='coerce')

# Filter the DataFrame based on the date and 'Primary Type'
filtered10_df = Chicago_Crime[(Chicago_Crime['Date'] >= "2023-05-13 12:00:00") & 
                              (Chicago_Crime['Primary Type'] == 'THEFT')]

# Display the filtered data
filtered10_df.head()
